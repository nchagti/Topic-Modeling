# %%
import json
import spacy
from spacy.tokens import DocBin
from collections import defaultdict


# Load the LatinCy model
nlp = spacy.load("la_core_web_lg")

# %%
# Load the original corpus
with open("./Acts/latin_tragedies_acts.json", "r", encoding="utf-8") as f:
    raw_corpus = json.load(f)

doc_bin = DocBin()
ids = []

# Serialize tragedies to disk
for entry in raw_corpus:
    doc = nlp(entry["text"])
    doc_bin.add(doc)
    ids.append(entry["id"])


# Save the DocBin to disk
doc_bin.to_disk("./Acts/latin_tragedies_acts.spacy")

# %%
# Target lemmas
target_words = {"stadium"}

# Dictionary to hold lemma occurrences
word_occurences = defaultdict(set)

# Load the DocBin from disk
doc_bin = DocBin().from_disk("./Acts/latin_tragedies_acts.spacy")

docs = list(doc_bin.get_docs(nlp.vocab))

# For each lemma, collect all token occurrences with detailed info            
for ids, doc in zip(ids, docs):
    for token in doc:
        if token.lemma_ in target_words or token.text.lower() in target_words:
            matched_word = token.lemma_ if token.lemma_ in target_words else token.text.lower()
            word_occurences[matched_word].add((ids, token.text, token.lemma_, token.sent, token.morph, token.pos_))

# Display results
for word, items in word_occurences.items():
    print(f"\n{word}:")
    for id, word, lemma, sentence, morph, pos in sorted(
        items, key=lambda x: (x[0], x[1])
        ):  
        print(f"  Play ID: {id}")
        print(f"    Word: {word}")
        print(f"    Lemma: {lemma}")
        print(f"    Context: {sentence}")
        print(f"    Morph: {morph}")
        print(f"    POS: {pos}")
        print()
# Out:
# stadium:
#   Play ID: seneca-thyestes_act1
#     Word: stadio
#     Lemma: stadium
#     Context: Argos de superis si quis Achaicum Pisaeasque domos curribus inclitas, Isthmi si quis amat regna Corinthii et portus geminos et mare dissidens, si quis Taygeti conspicuas nives, quas cum Sarmaticus tempore frigido in summis Boreas composuit iugis, aestas veliferis solvit Etesiis, quem tangit gelido flumine lucidus Alpheos, stadio notus Olympico, advertat placidum numen et arceat, alternae scelerum no redeant vices nec succedat avo deterior nepos et maior placeat culpa minoribus.
#     Morph: Case=Abl|Gender=Neut|Number=Sing
#     POS: NOUN
#
#   Play ID: seneca-thyestes_act3
#     Word: stadia
#     Lemma: stadium
#     Context: Optata patriae tecta et Argolicas opes miserisque summum ac maxime exulibus bonum, tractum soli natalis et patrios deos (si sunt tamen di) cerno, Cyclopum sacras turres, labore maius humano decus, celebrata iuveni stadia, per quae nobilis palmam paterno non semel curru tuli.
#     Morph: Case=Acc|Gender=Neut|Number=Plur
#     POS: NOUN
