# %%
import json
import spacy
from spacy.tokens import DocBin
from collections import defaultdict


# Load the LatinCy model
nlp = spacy.load("la_core_web_lg")

# %%
# Load the original corpus
with open("./Acts/latin_tragedies_acts.json", "r", encoding="utf-8") as f:
    raw_corpus = json.load(f)

doc_bin = DocBin()
ids = []

# Serialize tragedies to disk
for entry in raw_corpus:
    doc = nlp(entry["text"])
    doc_bin.add(doc)
    ids.append(entry["id"])


# Save the DocBin to disk
doc_bin.to_disk("./Acts/latin_tragedies_acts.spacy")

# %%
# Target lemmas
target_words = {"colus"}

# Dictionary to hold lemma occurrences
word_occurences = defaultdict(set)

# Load the DocBin from disk
doc_bin = DocBin().from_disk("./Acts/latin_tragedies_acts.spacy")

docs = list(doc_bin.get_docs(nlp.vocab))

# For each lemma, collect all token occurrences with detailed info            
for doc_id, doc in zip(ids, docs):
    for token in doc:
        if token.lemma_.lower() in target_words or token.text.lower() in target_words:
            matched_word = token.lemma_ if token.lemma_.lower() in target_words else token.text.lower()
            word_occurences[matched_word].add((doc_id, token.text, token.lemma_, token.sent, token.morph, token.pos_))

# Display results
for matched_word, items in word_occurences.items():
    print(f"\n{matched_word}:")
    for doc_id, word, lemma, sentence, morph, pos in sorted(
        items, key=lambda x: (x[0], x[1])
        ):  
        print(f"  Play ID: {doc_id}")
        print(f"    Word: {word}")
        print(f"    Lemma: {lemma}")
        print(f"    Context: {sentence}")
        print(f"    Morph: {morph}")
        print(f"    POS: {pos}")
        print()
# Out:
# colus:
#   Play ID: seneca-hercules-furens_act2
#     Word: colos
#     Lemma: colus
#     Context: Evincas utinam iura ferae Stygis Parcarumque colos non revocabiles.
#     Morph: Case=Acc|Gender=Masc|Number=Plur
#     POS: NOUN
#
#   Play ID: seneca-hercules-oetaeus_act1
#     Word: colus
#     Lemma: colus
#     Context: Iam iam dominae captiva colus fusosque legam, pro saeve decor formaque mortem paritura mihi, tibi cuncta domus concidit uni, dum me genitor negat Alcidae atque Herculeus socer esse timet, sed iam dominae tecta petantur.
#     Morph: Case=Nom|Gender=Masc|Number=Sing
#     POS: NOUN
#
#   Play ID: seneca-hercules-oetaeus_act2
#     Word: colu
#     Lemma: colus
#     Context: Prolata vis est quaeque Palladia colu lassavit omnem texta famularum manum.
#     Morph: Case=Nom|Gender=Fem|Number=Sing
#     POS: NOUN
#
#   Play ID: seneca-hercules-oetaeus_act2
#     Word: colus
#     Lemma: colus
#     Context: quaelibet herbae tinxere colus quas indoctae nevere manus:
#     Morph: Case=Acc|Gender=Masc|Number=Plur
#     POS: NOUN
#
#   Play ID: seneca-hercules-oetaeus_act2
#     Word: colus
#     Lemma: colus
#     Context: hospes Timoli Lydiam fovit nurum et amore captus ad leves sedit colus, udum feroci stamen intorquens manu.
#     Morph: Case=Nom|Gender=Masc|Number=Sing
#     POS: NOUN
#
#   Play ID: seneca-hercules-oetaeus_act3
#     Word: colus
#     Lemma: colus
#     Context: sic cum vinceret inferos Orpheus carmine funditus, consumptos iterum deae supplent Eurydices colus!
#     Morph: Case=Nom|Gender=Masc|Number=Sing
#     POS: NOUN
#
#   Play ID: seneca-hercules-oetaeus_act3
#     Word: colus
#     Lemma: colus
#     Context: nulli non avidi colus Parcas stamina nectere:
#     Morph: Case=Nom|Gender=Masc|Number=Sing
#     POS: NOUN
#
#   Play ID: seneca-hercules-oetaeus_act3
#     Word: colus
#     Lemma: colus
#     Context: Mors refugit illum victa quae in regno suo semel est nec audent fata tam vastum nefas admittere, ipsas forsitan trepida colus Clotho manu proiecit et fata Herculis timet peragere, pro diem, infandum diem!
#     Morph: Case=Nom|Gender=Masc|Number=Sing
#     POS: NOUN
#
#   Play ID: seneca-hercules-oetaeus_act4
#     Word: colus
#     Lemma: colus
#     Context: invicta si me cadere feminea manu voluere fata perque tam turpes colus mea mors cucurrit, cadere potuissem, ei mihi, Iunonis odio:
#     Morph: Case=Nom|Gender=Masc|Number=Sing
#     POS: NOUN
#
#   Play ID: seneca-oedipus_act5
#     Word: colus
#     Lemma: colus
#     Context: quicquid patimur mortale genus, quicquid facimus venit ex alto, servatque suae decreta colus.
#     Morph: Case=Nom|Gender=Masc|Number=Sing
#     POS: NOUN
