# %% [markdown]
# ### Tokenize and Lemmatize Acts

# %%
# %pip install https://huggingface.co/latincy/la_core_web_lg/resolve/main/la_core_web_lg-3.8.0-py3-none-any.whl
# Out:
# Collecting la-core-web-lg==3.8.0
#   Downloading https://huggingface.co/latincy/la_core_web_lg/resolve/main/la_core_web_lg-3.8.0-py3-none-any.whl (242.2 MB)
#      ---------------------------------------- 0.0/242.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/242.2 MB ? eta -:--:--
#      ---------------------------------------- 0.8/242.2 MB 8.5 MB/s eta 0:00:29
#       -------------------------------------- 3.7/242.2 MB 11.5 MB/s eta 0:00:21
#       -------------------------------------- 5.8/242.2 MB 11.4 MB/s eta 0:00:21
#      - ------------------------------------- 8.1/242.2 MB 11.7 MB/s eta 0:00:20
#      - ------------------------------------ 10.7/242.2 MB 11.6 MB/s eta 0:00:20
#      -- ----------------------------------- 13.1/242.2 MB 11.4 MB/s eta 0:00:21
#      -- ----------------------------------- 15.7/242.2 MB 11.5 MB/s eta 0:00:20
#      -- ----------------------------------- 18.4/242.2 MB 11.6 MB/s eta 0:00:20
#      --- ---------------------------------- 20.2/242.2 MB 11.3 MB/s eta 0:00:20
#      --- ---------------------------------- 22.5/242.2 MB 11.3 MB/s eta 0:00:20
#      --- ---------------------------------- 25.4/242.2 MB 11.4 MB/s eta 0:00:19
#      ---- --------------------------------- 27.8/242.2 MB 11.4 MB/s eta 0:00:19
#      ---- --------------------------------- 30.4/242.2 MB 11.5 MB/s eta 0:00:19
#      ----- -------------------------------- 33.0/242.2 MB 11.5 MB/s eta 0:00:19
#      ----- -------------------------------- 35.7/242.2 MB 11.5 MB/s eta 0:00:18
#      ----- -------------------------------- 38.0/242.2 MB 11.6 MB/s eta 0:00:18
#      ------ ------------------------------- 40.6/242.2 MB 11.5 MB/s eta 0:00:18
#      ------ ------------------------------- 43.0/242.2 MB 11.6 MB/s eta 0:00:18
#      ------- ------------------------------ 45.6/242.2 MB 11.6 MB/s eta 0:00:17
#      ------- ------------------------------ 48.2/242.2 MB 11.6 MB/s eta 0:00:17
#      ------- ------------------------------ 50.6/242.2 MB 11.6 MB/s eta 0:00:17
#      -------- ----------------------------- 53.2/242.2 MB 11.6 MB/s eta 0:00:17
#      -------- ----------------------------- 55.8/242.2 MB 11.6 MB/s eta 0:00:17
#      --------- ---------------------------- 58.5/242.2 MB 11.6 MB/s eta 0:00:16
#      --------- ---------------------------- 60.8/242.2 MB 11.6 MB/s eta 0:00:16
#      --------- ---------------------------- 63.4/242.2 MB 11.7 MB/s eta 0:00:16
#      ---------- --------------------------- 66.1/242.2 MB 11.7 MB/s eta 0:00:16
#      ---------- --------------------------- 68.7/242.2 MB 11.7 MB/s eta 0:00:15
#      ----------- -------------------------- 71.0/242.2 MB 11.7 MB/s eta 0:00:15
#      ----------- -------------------------- 73.7/242.2 MB 11.7 MB/s eta 0:00:15
#      ----------- -------------------------- 76.0/242.2 MB 11.7 MB/s eta 0:00:15
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: still running...
#   Getting requirements to build wheel: still running...
#   Getting requirements to build wheel: still running...
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: spacy<3.9.0,>=3.8.3 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from la-core-web-lg==3.8.0) (3.8.11)
# Requirement already satisfied: setuptools in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy_lookups_data@ git+https://github.com/diyclassics/spacy-lookups-data.git#egg=spacy-lookups-data->la-core-web-lg==3.8.0) (80.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (2.12.5)
# Requirement already satisfied: jinja2 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (3.1.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (0.1.5)
# Requirement already satisfied: colorama in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\dropbox\nits\syracuse\ecerinis_dh\topic modeling\gensim-env\lib\site-packages (from jinja2->spacy<3.9.0,>=3.8.3->la-core-web-lg==3.8.0) (3.0.2)
# Building wheels for collected packages: spacy_lookups_data
#   Building wheel for spacy_lookups_data (pyproject.toml): started
#   Building wheel for spacy_lookups_data (pyproject.toml): finished with status 'done'
#   Created wheel for spacy_lookups_data: filename=spacy_lookups_data-1.0.5-py2.py3-none-any.whl size=100463226 sha256=9d3881dc53b1dcc4359998a2d31790ec73084436bd726d63c85c8e9edbbecee1
#   Stored in directory: C:\Users\dell\AppData\Local\Temp\pip-ephem-wheel-cache-6v32jv4a\wheels\51\65\b9\cc9ddb1b5331d1448963a943e3a9614f3b5e1f7c45844b4ae6
# Successfully built spacy_lookups_data
# Installing collected packages: spacy_lookups_data, la-core-web-lg
#
#    ---------------------------------------- 0/2 [spacy_lookups_data]
#    ---------------------------------------- 0/2 [spacy_lookups_data]
#    ---------------------------------------- 0/2 [spacy_lookups_data]
#    ---------------------------------------- 0/2 [spacy_lookups_data]
#    ---------------------------------------- 0/2 [spacy_lookups_data]
#    ---------------------------------------- 0/2 [spacy_lookups_data]
#    ---------------------------------------- 0/2 [spacy_lookups_data]
#    ---------------------------------------- 0/2 [spacy_lookups_data]
#    ---------------------------------------- 0/2 [spacy_lookups_data]
#    ---------------------------------------- 0/2 [spacy_lookups_data]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    -------------------- ------------------- 1/2 [la-core-web-lg]
#    ---------------------------------------- 2/2 [la-core-web-lg]
#
# Successfully installed la-core-web-lg-3.8.0 spacy_lookups_data-1.0.5
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/diyclassics/spacy-lookups-data.git 'C:\Users\dell\AppData\Local\Temp\pip-install-muc9yovd\spacy-lookups-data_8332b4a53281491aabf867f589442cd2'

# %%
# Using spacy.load().
import spacy
nlp = spacy.load("la_core_web_lg")

# %%
import json

with open("../stopwords_latin.json", "r", encoding="utf-8") as f:
    stopwords_json = json.load(f)

latin_stopwords = set()

for category, items in stopwords_json.items():
    if isinstance(items, list):
        # Case 1: Simple list of stopwords
        latin_stopwords.update(word.lower() for word in items)
    elif isinstance(items, dict):
        # Case 2: Nested dictionary (e.g., "Pronouns")
        for lemma, forms in items.items():
            latin_stopwords.add(lemma.lower())                     # include the lemma
            latin_stopwords.update(word.lower() for word in forms) # include all word forms

# %%
token = nlp("ablatus")[0]
print(token.lemma_) #returns incorrect lemma (ablatus) before custom lemma lookup
# Out:
# ablatus

# %%
#create custom lemma lookup for 'inquit' and 'ablatus'
from spacy import Language
from spacy.lookups import Lookups

lookups = Lookups()

custom_lemma_lookups = {
    "inquam": ["inquit"],
    "aufero": ["ablatus"]
}

custom_lookups = {}
for key, values in custom_lemma_lookups.items():
    for value in values:
        if value not in lookups:
            custom_lookups[value] = key

@Language.component(name="custom_lookup_lemmatizer")
def make_lookup_lemmatizer_function(doc):
    for token in doc:
        token.lemma_ = custom_lookups.get(token.text, token.lemma_)
    return doc

try:
    nlp.add_pipe("custom_lookup_lemmatizer", name="custom_lookup_lemmatizer")
except:
    # If the pipeline component is already added, we can't add it again
    pass

# %%
token = nlp("ablatus")[0]
print(token.lemma_) #returns "aufero" after custom lemma lookup
# Out:
# aufero

# %%
def process_latin_text(text, title=None, act=None):
    doc = nlp(text)
    # Tokenize, lowercase, lemmatize
    tokens = [token.lemma_.lower() for token in doc if token.is_alpha and token.lemma_.lower() not in latin_stopwords and token.pos_ in ["PROPN", "NOUN", "VERB", "ADJ"]]
    
    if "fata" in tokens:
        print(f"'fata' found in {title}, {act}, text: {text[:100]}")
        for token in doc:
            if token.text.lower() == "fata":
                print(f"  Token 'fata' lemmatized as: '{token.lemma_}' (POS: {token.pos_})")

    return tokens

# %%
# Load the acts
with open("latin_tragedies_acts.json", "r", encoding="utf-8") as f:
    acts = json.load(f)

# Process each act and store tokens with id, play_slug, title, author and act
processed_acts = []
for tragedy_act in acts:
    tokens = process_latin_text(tragedy_act["text"], tragedy_act["title"], tragedy_act["act"])
    processed_tragedy_act = {
        "id": tragedy_act["id"],
        "play_slug": tragedy_act["play_slug"],
        "title": tragedy_act["title"],
        "author": tragedy_act["author"],
        "act": tragedy_act["act"],
        "tokens": tokens
    }
    processed_acts.append(processed_tragedy_act)

# Now `processed_acts` is a list of dictionaries like:
# {"title": "...", "author": "...", "tokens": [...]}
# Out:
# 'fata' found in Oedipus, 4, text: Curas revolvit animus et repetit metus,
# obisse nostro Laium scelere autumant
# superi inferique, sed a
#   Token 'fata' lemmatized as: 'fatum' (POS: NOUN)
#   Token 'fata' lemmatized as: 'fatum' (POS: NOUN)
#   Token 'fata' lemmatized as: 'Fata' (POS: NOUN)
# 'fata' found in Oedipus, 5, text: Praedicta postquam fata et infandum genus
# deprendit ac se scelere convictum Oedipus
# damnavit ipse, r
#   Token 'fata' lemmatized as: 'fatum' (POS: NOUN)
#   Token 'fata' lemmatized as: 'fatum' (POS: NOUN)
#   Token 'fata' lemmatized as: 'fatum' (POS: NOUN)
#   Token 'fata' lemmatized as: 'Fata' (POS: PROPN)

# %%
import json

with open("latin_tragedies_acts.json", "r", encoding="utf-8") as f:
    acts = json.load(f)

total_acts = len(acts)
print(f"Total acts across all plays: {total_acts}")
# Out:
# Total acts across all plays: 56

# %%
with open("processed_acts.json", "w", encoding="utf-8") as f:
    json.dump(processed_acts, f, ensure_ascii=False, indent=2)

# %%
import pickle

# Save the processed corpus to a .pkl file to use in python
with open("processed_acts.pkl", "wb") as f:
    pickle.dump(processed_acts, f)

# %%
# Load the processed acts from the .pkl file
with open("processed_acts.pkl", "rb") as f:
    processed_acts = pickle.load(f)

# access tokens directly
tokens_1 = processed_acts[0]["tokens"]
print(type(tokens_1))  # Should be <class 'list'>
# Out:
# <class 'list'>

# %%
len(tokens_1)
# Out:
# 389

# %%
tragedy_act_title = processed_acts[0]['title']
print(tragedy_act_title)
# Out:
# Agamemnon

# %%
tragedy_act_number = processed_acts[0]['act']
print(tragedy_act_number)
# Out:
# 1
